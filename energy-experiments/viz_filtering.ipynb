# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

# %%
def get_energy_from_experiment(file_path):
    df = pd.read_excel(file_path, skiprows=range(0, 4))
    df.columns = df.columns.str.strip()

    # exp_name = file_name.split('.')[0]
    df['W'] = df['Voltage  (V)'] * df['Current  (A)']
    df.drop(columns=['Time （s）', 'Voltage  (V)', 'Current  (A)'], inplace=True)

    df = df.truncate(before=15, after=75)
    return (df['W'].mean() * len(df['W']) / 3600)

# %%
# print(round(get_energy_from_experiment('filter-data/pixel-1_5ghz.xlsx'), 3))
# print(round(get_energy_from_experiment('filter-data/pixel-1_8ghz.xlsx'), 3))
# print(round(get_energy_from_experiment('filter-data/pixel-2_1ghz.xlsx'), 3))
# print(round(get_energy_from_experiment('filter-data/pixel-2_4ghz.xlsx'), 3))

print(round(get_energy_from_experiment('filter-data/pixel-2_4ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/area-2_4ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/edge-2_4ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/sparse-2_4ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/none-2_4ghz-30fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data/pixel-2_1ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/area-2_1ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/edge-2_1ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/sparse-2_1ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/none-2_1ghz-30fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data/pixel-1_8ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/area-1_8ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/edge-1_8ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/sparse-1_8ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/none-1_8ghz-30fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data/pixel-1_5ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/area-1_5ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/edge-1_5ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/sparse-1_5ghz-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/none-1_5ghz-30fps.xlsx'), 3))
# Out:
# 0.078
# 0.094
# 0.106
# 0.093
# 0.07
#
# 0.072
# 0.082
# 0.093
# 0.085
# 0.064
#
# 0.067
# 0.079
# 0.085
# 0.077
# 0.059
#
# 0.055
# 0.064
# 0.071
# 0.064
# 0.052

# %%
cpu_freq = [1.5, 1.8, 2.1, 2.4]
pixel_filter_energy = [0.055, 0.067, 0.072, 0.078]
area_filter_energy = [0.064, 0.079, 0.082, 0.094]
edge_filter_energy = [0.071, 0.085, 0.093, 0.106]
sparse_filter_energy = [0.064, 0.077, 0.085, 0.093]
none_filter_energy = [0.052, 0.059, 0.064, 0.07]

plt.plot(cpu_freq, pixel_filter_energy, 'o--', label='Pixel')
plt.plot(cpu_freq, area_filter_energy, 'o--', label='Area')
plt.plot(cpu_freq, edge_filter_energy, 'o--', label='Edge')
plt.plot(cpu_freq, sparse_filter_energy, 'o--', label='Lucas-Kanade Optical Flow')
plt.plot(cpu_freq, none_filter_energy, 'o--', label='None')
plt.title('CPU Frequency vs. Energy (30 fps)')
plt.xlabel('CPU Frequency (GHz)')
plt.ylabel('Energy (Wh)')
plt.grid(True, axis='y')
plt.legend()
plt.show()

# %%
print(round(get_energy_from_experiment('filter-data/h264-5fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/h264-10fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/h264-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/h264-20fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/h264-25fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data/h264-30fps.xlsx'), 3))

print(round(get_energy_from_experiment('fps-bitrate/h264-1_5ghz-10fps.xlsx'), 3))
# Out:
# 0.072
# 0.079
# 0.085
# 0.093
# 0.098
# 0.106
# 0.057

# %%
fps = [4.99, 9.99, 14.97, 19.93, 24.71, 28.98]

encoding_energy_2_4ghz = [0.072, 0.079, 0.085, 0.093, 0.098, 0.106]
encoding_energy_1_5ghz = [0.057]
plt.plot(fps, encoding_energy_2_4ghz, 'o--')
plt.title('H264 Stream FPS vs. Energy')
plt.xlabel('FPS')
plt.ylabel('Energy (Wh)')
plt.grid(True, axis='y')
plt.show()

# %%
print(round(get_energy_from_experiment('fps-bitrate/h264-1M-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('fps-bitrate/h264-10M-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('fps-bitrate/h264-25M-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('fps-bitrate/h264-50M-30fps.xlsx'), 3))
print(round(get_energy_from_experiment('fps-bitrate/h264-100M-30fps.xlsx'), 3))
# Out:
# 0.096
# 0.099
# 0.104
# 0.109
# 0.104

# %%
bitrate_energy = [0.096, 0.099, 0.104, 0.109, 0.104]
bitrate_energy_fps = [0.096 / 29.899, 0.099 / 29.681, 0.104 / 28.464, 0.109 / 28.842, 0.104 / 23.135]
for i in range(len(bitrate_energy_fps)):
    bitrate_energy_fps[i] = bitrate_energy_fps[i] / 60 # Convert to energy / frame instead of energy / fps
bitrates = [1, 10, 25, 50, 100]

# plt.plot(bitrates, bitrate_energy, 'o--')
plt.plot(bitrates, bitrate_energy_fps, 'o--')
plt.title('H264 Bitrate vs. Energy')
plt.xlabel('Bitrate (Mbps)')
plt.ylabel('Energy (Wh) per Frame')
plt.grid(True, axis='y')
plt.show()

# %%
print(round(get_energy_from_experiment('filter-data2/15fps/encode-1_5ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/encode-1_8ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/encode-2_1ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/encode-2_4ghz-15fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data2/15fps/pixel-encode-1_5ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/pixel-encode-1_8ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/pixel-encode-2_1ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/pixel-encode-2_4ghz-15fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data2/15fps/area-encode-1_5ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/area-encode-1_8ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/area-encode-2_1ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/area-encode-2_4ghz-15fps.xlsx'), 3))
print()

print(round(get_energy_from_experiment('filter-data2/15fps/edge-encode-1_5ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/edge-encode-1_8ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/edge-encode-2_1ghz-15fps.xlsx'), 3))
print(round(get_energy_from_experiment('filter-data2/15fps/edge-encode-2_4ghz-15fps.xlsx'), 3))
print()
# Out:
# 0.06
# 0.071
# 0.074
# 0.082
#
# 0.064
# 0.074
# 0.078
# 0.086
#
# 0.066
# 0.079
# 0.085
# 0.092
#
# 0.068
# 0.087
# 0.093
# 0.102

# %%
# Visualizations after feedback to go client-driven
cpu_freq = np.array([1.5, 1.8, 2.1, 2.4])
idle_energy = np.array([0.051, 0.056, 0.059, 0.063])
encode_energy = np.array([0.06, 0.071, 0.074, 0.082]) # Read, encode
pixel_encode_energy = np.array([0.064, 0.074, 0.078, 0.086]) # Read, encode, feature
area_encode_energy = np.array([0.066, 0.079, 0.085, 0.092]) # Read, encode, feature
edge_encode_energy = np.array([0.068, 0.087, 0.093, 0.102]) # Read, encode, feature

plt.plot(cpu_freq, idle_energy, 'o--', label='Idle')
plt.plot(cpu_freq, encode_energy, 'o--', label='Encode')
plt.plot(cpu_freq, pixel_encode_energy, 'o--', label='Pixel')
plt.plot(cpu_freq, area_encode_energy, 'o--', label='Area')
plt.plot(cpu_freq, edge_encode_energy, 'o--', label='Edge')
plt.xticks(cpu_freq)
plt.title('CPU Frequency vs. Energy (15 fps)')
plt.xlabel('CPU Frequency (GHz)')
plt.ylabel('Energy (Wh)')
plt.grid(True, axis='y')
plt.legend()
plt.show()

bar_width = 0.25
plt.bar(cpu_freq, idle_energy, width=bar_width, label='Idle')
plt.bar(cpu_freq, encode_energy-idle_energy, width=bar_width, bottom=idle_energy, label='Encode')
plt.bar(cpu_freq, pixel_encode_energy-encode_energy, width=bar_width, bottom=encode_energy, label='Pixel')
plt.bar(cpu_freq, area_encode_energy-pixel_encode_energy, width=bar_width, bottom=pixel_encode_energy, label='Area')
plt.bar(cpu_freq, edge_encode_energy-area_encode_energy, width=bar_width, bottom=area_encode_energy, label='Edge')
plt.xticks(cpu_freq)

plt.title('CPU Frequency vs. Energy (15 fps)')
plt.xlabel('CPU Frequency (GHz)')
plt.ylabel('Energy (Wh)')
plt.grid(True, axis='y')
plt.legend()
plt.show()
